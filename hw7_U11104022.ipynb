# %%
import numpy as np

# %%
lon=12.1878; lat=48.1195; ele=487.9;Go=980717.39

# %%
Ge=978031.85

# %%
np.pi
# Out:
# 3.141592653589793

# %%
print(np.sin(0))
# Out:
# 0.0

# %%
lat=48.1195

# %%
lat_r=lat*np.pi/180

# %%
np.sin(lat_r)
# Out:
# np.float64(0.7445387927201025)

# %%
Gt=Ge*(1+0.005278895*np.sin(lat_r)**2+0.000023462*np.sin(lat_r)**4)

# %%
FAC=ele*0.308

# %%
BC=0.112*ele

# %%
(Go+FAC)-Gt
# Out:
# np.float64(-33.24501448520459)

# %%
print("theoretical gravity: {Gt}")
# Out:
# theoretical gravity: {Gt}
